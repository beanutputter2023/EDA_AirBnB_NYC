# %% [markdown]
# ### Preliminary Data Inspection

# %% [markdown]
# ##### Getting data from Databricks catalog

# %%
df = spark.table("workspace.default.ab_nyc_2019")
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood_group</th><th>neighbourhood</th><th>latitude</th><th>longitude</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>last_review</th><th>reviews_per_month</th><th>calculated_host_listings_count</th><th>availability_365</th></tr></thead><tbody><tr><td>2539</td><td>Clean & quiet apt home by the park</td><td>2787</td><td>John</td><td>Brooklyn</td><td>Kensington</td><td>40.64749</td><td>-73.97237</td><td>Private room</td><td>149</td><td>1</td><td>9</td><td>2018-10-19</td><td>0.21</td><td>6</td><td>365</td></tr><tr><td>2595</td><td>Skylit Midtown Castle</td><td>2845</td><td>Jennifer</td><td>Manhattan</td><td>Midtown</td><td>40.75362</td><td>-73.98377</td><td>Entire home/apt</td><td>225</td><td>1</td><td>45</td><td>2019-05-21</td><td>0.38</td><td>2</td><td>355</td></tr><tr><td>3647</td><td>THE VILLAGE OF HARLEM....NEW YORK !</td><td>4632</td><td>Elisabeth</td><td>Manhattan</td><td>Harlem</td><td>40.80902</td><td>-73.9419</td><td>Private room</td><td>150</td><td>3</td><td>0</td><td>null</td><td>null</td><td>1</td><td>365</td></tr><tr><td>3831</td><td>Cozy Entire Floor of Brownstone</td><td>4869</td><td>LisaRoxanne</td><td>Brooklyn</td><td>Clinton Hill</td><td>40.68514</td><td>-73.95976</td><td>Entire home/apt</td><td>89</td><td>1</td><td>270</td><td>2019-07-05</td><td>4.64</td><td>1</td><td>194</td></tr><tr><td>5022</td><td>Entire Apt: Spacious Studio/Loft by central park</td><td>7192</td><td>Laura</td><td>Manhattan</td><td>East Harlem</td><td>40.79851</td><td>-73.94399</td><td>Entire home/apt</td><td>80</td><td>10</td><td>9</td><td>2018-11-19</td><td>0.1</td><td>1</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ##### Basic info and shape

# %%
print(f"Total rows: {df.count()}")
print(f"Total columns: {len(df.columns)}")
# Out:
# Total rows: 49079
# Total columns: 16

# %% [markdown]
# ##### Exploring Table schema

# %%
df.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- host_id: long (nullable = true)
#  |-- host_name: string (nullable = true)
#  |-- neighbourhood_group: string (nullable = true)
#  |-- neighbourhood: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- price: long (nullable = true)
#  |-- minimum_nights: long (nullable = true)
#  |-- number_of_reviews: long (nullable = true)
#  |-- last_review: date (nullable = true)
#  |-- reviews_per_month: double (nullable = true)
#  |-- calculated_host_listings_count: long (nullable = true)
#  |-- availability_365: long (nullable = true)

# %% [markdown]
# ##### Summary Statistics

# %%
display(df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>id</th><th>name</th><th>host_id</th><th>host_name</th><th>neighbourhood_group</th><th>neighbourhood</th><th>latitude</th><th>longitude</th><th>room_type</th><th>price</th><th>minimum_nights</th><th>number_of_reviews</th><th>reviews_per_month</th><th>calculated_host_listings_count</th><th>availability_365</th></tr></thead><tbody><tr><td>count</td><td>48895</td><td>49047</td><td>48735</td><td>48873</td><td>48894</td><td>48894</td><td>48891</td><td>48737</td><td>48894</td><td>48891</td><td>48893</td><td>48738</td><td>38863</td><td>48891</td><td>48737</td></tr><tr><td>mean</td><td>1.9017143236179568E7</td><td>1.02037532075E8</td><td>6.749845889059198E7</td><td>NaN</td><td>1.97400421E8</td><td>40.738701602564106</td><td>40.363071563477966</td><td>-73.9475341842947</td><td>154.36390484276728</td><td>152.22607432860855</td><td>7.119955821896795</td><td>23.257642906971974</td><td>1.3744471605383277</td><td>7.653883127774028</td><td>112.61000882286558</td></tr><tr><td>stddev</td><td>1.0983108385610096E7</td><td>8.709090084371348E7</td><td>7.855624635403281E7</td><td>NaN</td><td>null</td><td>0.06397153716374615</td><td>6.466708348941253</td><td>0.7354974291831097</td><td>513.660806114728</td><td>238.52839336353705</td><td>20.805063812845706</td><td>44.556023366233944</td><td>1.6943302852354718</td><td>34.82174958890119</td><td>131.6061838672227</td></tr><tr><td>min</td><td>2539</td><td> 1 Bed Apt in Utopic Williamsburg </td><td>2438</td><td>'Cil</td><td>197400421</td><td>40.54268</td><td>-74.16254</td><td>-74.24442</td><td>-73.90783</td><td>0</td><td>0</td><td>0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>max</td><td>36487245</td><td>ﾏﾝﾊｯﾀﾝ､駅から徒歩4分でどこに行くのにも便利な場所!女性の方希望,ｷﾚｲなお部屋｡</td><td>274321313</td><td>현선</td><td>Woodside</td><td>Woodside</td><td>40.91306</td><td>40.68328</td><td>Shared room</td><td>10000</td><td>1250</td><td>629</td><td>58.5</td><td>365</td><td>365</td></tr></tbody></table></div>

# %% [markdown]
# ##### Duplicates & Null summary per column

# %%
from pyspark.sql import Row
from pyspark.sql.functions import *
total_rows = df.count()
summary_rows = []
schema = dict(df.dtypes)
for column in df.columns:
  duplicate_df = df.groupBy(column).agg(count('*').alias('count')).filter(col('count')>1)
  duplicate_row_count = duplicate_df.agg({"count":"sum"}).collect()[0][0] 

  if duplicate_row_count is None:
      duplicate_row_count = 0

  duplicate_percentage = (duplicate_row_count / total_rows)*100 if total_rows > 0 else 0
  
  if schema[column] in ['int', 'bigint', 'double', 'float', 'decimal']:
      null_count = df.filter(col(column).isNull()|isnan(col(column))).count()
  else:
      null_count = df.filter(col(column).isNull()).count()

  null_percentage = (null_count / total_rows)*100 if total_rows > 0 else 0


  summary_rows.append(Row(
  column_name = column,
  duplicate_count = duplicate_row_count,
  duplicate_percentage = duplicate_percentage,
  null_count = null_count,
  null_percentage = null_percentage
  )) 

summary_df = spark.createDataFrame(summary_rows)
display(summary_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>column_name</th><th>duplicate_count</th><th>duplicate_percentage</th><th>null_count</th><th>null_percentage</th></tr></thead><tbody><tr><td>id</td><td>184</td><td>0.3749057641761242</td><td>184</td><td>0.3749057641761242</td></tr><tr><td>name</td><td>1699</td><td>3.4617657246480165</td><td>32</td><td>0.06520100246541291</td></tr><tr><td>host_id</td><td>16837</td><td>34.305914953442404</td><td>344</td><td>0.7009107765031888</td></tr><tr><td>host_name</td><td>42189</td><td>85.96140915666578</td><td>206</td><td>0.41973145337109563</td></tr><tr><td>neighbourhood_group</td><td>49045</td><td>99.93072393488049</td><td>185</td><td>0.37694329550316835</td></tr><tr><td>neighbourhood</td><td>48916</td><td>99.6678823936918</td><td>185</td><td>0.37694329550316835</td></tr><tr><td>latitude</td><td>41846</td><td>85.26253591148964</td><td>188</td><td>0.3830558894843008</td></tr><tr><td>longitude</td><td>43913</td><td>89.47411316448989</td><td>342</td><td>0.6968357138491004</td></tr><tr><td>room_type</td><td>49034</td><td>99.90831109028301</td><td>185</td><td>0.37694329550316835</td></tr><tr><td>price</td><td>48907</td><td>99.64954461174841</td><td>188</td><td>0.3830558894843008</td></tr><tr><td>minimum_nights</td><td>49031</td><td>99.90219849630189</td><td>186</td><td>0.3789808268302125</td></tr><tr><td>number_of_reviews</td><td>49004</td><td>99.84718515047169</td><td>341</td><td>0.6947981825220563</td></tr><tr><td>last_review</td><td>48843</td><td>99.51914260681758</td><td>10373</td><td>21.135312455429002</td></tr><tr><td>reviews_per_month</td><td>48925</td><td>99.6862201756352</td><td>10216</td><td>20.815420037083072</td></tr><tr><td>calculated_host_listings_count</td><td>49009</td><td>99.85737280710691</td><td>188</td><td>0.3830558894843008</td></tr><tr><td>availability_365</td><td>49079</td><td>100.0</td><td>342</td><td>0.6968357138491004</td></tr></tbody></table></div>

# %% [markdown]
# ##### Dropping nulls and assessing data loss in doing so

# %%
clean_df = df.dropna()

# %%
print(f"Original rows: {df.count()}")
print(f"Cleaned rows:{clean_df.count()}")

print(f"Rows removed: {df.count() - clean_df.count()}")
print(f"Percentage removed: {(df.count() - clean_df.count()) / df.count()*100}")
# Out:
# Original rows: 49079
# Cleaned rows:38678
# Rows removed: 10401
# Percentage removed: 21.19236333258624

# %% [markdown]
# ### Categorical Insights

# %% [markdown]
# #### room_type Insights

# %% [markdown]
# ##### Flagging Invalid room_type values
# Assuming ('Entire home/apt', 'Private room', 'Shared room') are valid room_type categories for insights. This field also consists of numeric and null values which do not give any information in relation to the room type in an AirBnB listing.

# %%
valid_room_type = ['Entire home/apt', 'Private room', 'Shared room']

df_room_flagged = df.select('id', 'room_type').withColumn('room_type_flagged', when(col('room_type').isin(valid_room_type), 'valid').otherwise('invalid'))
display(df_room_flagged)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>room_type</th><th>room_type_flagged</th></tr></thead><tbody><tr><td>2539</td><td>Private room</td><td>valid</td></tr><tr><td>2595</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>3647</td><td>Private room</td><td>valid</td></tr><tr><td>3831</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>5022</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>5099</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>5121</td><td>Private room</td><td>valid</td></tr><tr><td>5178</td><td>Private room</td><td>valid</td></tr><tr><td>5203</td><td>Private room</td><td>valid</td></tr><tr><td>5238</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>5295</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>5441</td><td>Private room</td><td>valid</td></tr><tr><td>5803</td><td>Private room</td><td>valid</td></tr><tr><td>6021</td><td>Private room</td><td>valid</td></tr><tr><td>6090</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>6848</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>7097</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>7322</td><td>Private room</td><td>valid</td></tr><tr><td>7726</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>7750</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>7801</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>8024</td><td>Private room</td><td>valid</td></tr><tr><td>8025</td><td>Private room</td><td>valid</td></tr><tr><td>8110</td><td>Private room</td><td>valid</td></tr><tr><td>8490</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>8505</td><td>Private room</td><td>valid</td></tr><tr><td>8700</td><td>Private room</td><td>valid</td></tr><tr><td>9357</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>9518</td><td>Private room</td><td>valid</td></tr><tr><td>9657</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>9668</td><td>Private room</td><td>valid</td></tr><tr><td>9704</td><td>Private room</td><td>valid</td></tr><tr><td>9782</td><td>Private room</td><td>valid</td></tr><tr><td>9783</td><td>Private room</td><td>valid</td></tr><tr><td>10452</td><td>Private room</td><td>valid</td></tr><tr><td>10962</td><td>Private room</td><td>valid</td></tr><tr><td>11452</td><td>Private room</td><td>valid</td></tr><tr><td>11708</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>11943</td><td>Private room</td><td>valid</td></tr><tr><td>12048</td><td>Shared room</td><td>valid</td></tr><tr><td>12192</td><td>Private room</td><td>valid</td></tr><tr><td>12299</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>12303</td><td>Private room</td><td>valid</td></tr><tr><td>12318</td><td>Private room</td><td>valid</td></tr><tr><td>12343</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>12627</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>12937</td><td>Private room</td><td>valid</td></tr><tr><td>12940</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>13050</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>13394</td><td>Private room</td><td>valid</td></tr><tr><td>13808</td><td>Private room</td><td>valid</td></tr><tr><td>14287</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>14290</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>14314</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>14322</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>14377</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>14991</td><td>Private room</td><td>valid</td></tr><tr><td>15220</td><td>Private room</td><td>valid</td></tr><tr><td>15338</td><td>Private room</td><td>valid</td></tr><tr><td>15341</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>15385</td><td>Private room</td><td>valid</td></tr><tr><td>15396</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>15711</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>16326</td><td>Entire home/apt</td><td>valid</td></tr><tr><td>16338</td><td>Private room</td><td> ...

# %% [markdown]
# ##### room_type Popularity

# %%
valid_df = df.filter(col('room_type').isin(valid_room_type))
most_popular = valid_df.groupBy('room_type').count().orderBy(desc("count"))
least_popular = valid_df.groupBy('room_type').count().orderBy(asc("count"))
display(valid_df.groupBy('room_type').count().orderBy(desc("count")))

print("Most Popular room type:", most_popular.first()['room_type'])
print("Least Popular room type:", least_popular.first()['room_type'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>room_type</th><th>count</th></tr></thead><tbody><tr><td>Entire home/apt</td><td>25348</td></tr><tr><td>Private room</td><td>22229</td></tr><tr><td>Shared room</td><td>1158</td></tr></tbody></table></div>
# Most Popular room type: Entire home/apt
# Least Popular room type: Shared room

# %% [markdown]
# ##### Average Price per valid room_type

# %%
 most_expensive_room_type = valid_df.groupBy('room_type').agg(round(avg('price'),2).alias('avg_price')).orderBy(desc("avg_price"))
 least_expensive_room_type = valid_df.groupBy('room_type').agg(round(avg('price'),2).alias('avg_price')).orderBy(asc("avg_price"))
 display(price_per_room)
 print("Most Expensive Room Type: ", most_expensive_room_type.first()['room_type'])
 print("Least Expensive Room Type: ", least_expensive_room_type.first()['room_type'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>room_type</th><th>avg_price</th></tr></thead><tbody><tr><td>Entire home/apt</td><td>211.88</td></tr><tr><td>Private room</td><td>89.51</td></tr><tr><td>Shared room</td><td>70.13</td></tr></tbody></table></div>
# Most Expensive Room Type:  Entire home/apt
# Least Expensive Room Type:  Shared room

# %% [markdown]
# #### Geographical Insights

# %% [markdown]
# ##### Popularity of neighbourhood_group

# %%
neighbourhood_group_df = df.filter(col('neighbourhood_group').isNotNull()).groupBy('neighbourhood_group').agg(count('*').alias('count'))

display(neighbourhood_group_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood_group</th><th>count</th></tr></thead><tbody><tr><td>East Elmhurst</td><td>2</td></tr><tr><td>Greenwich Village</td><td>2</td></tr><tr><td>Crown Heights</td><td>3</td></tr><tr><td>Elmhurst</td><td>7</td></tr><tr><td>Woodhaven</td><td>3</td></tr><tr><td>Brooklyn</td><td>20057</td></tr><tr><td>SoHo</td><td>1</td></tr><tr><td>Bronx</td><td>1080</td></tr><tr><td>Bedford-Stuyvesant</td><td>9</td></tr><tr><td>Chelsea</td><td>2</td></tr><tr><td>East Harlem</td><td>5</td></tr><tr><td>Bushwick</td><td>4</td></tr><tr><td>Astoria</td><td>2</td></tr><tr><td>Jackson Heights</td><td>2</td></tr><tr><td>East New York</td><td>1</td></tr><tr><td>Midwood</td><td>3</td></tr><tr><td>Woodside</td><td>1</td></tr><tr><td>Prospect-Lefferts Gardens</td><td>2</td></tr><tr><td>Stuyvesant Town</td><td>1</td></tr><tr><td>Brooklyn Heights</td><td>1</td></tr><tr><td>Manhattan</td><td>21598</td></tr><tr><td>Randall Manor</td><td>1</td></tr><tr><td>Washington Heights</td><td>4</td></tr><tr><td>Nadia</td><td>1</td></tr><tr><td>Long Island City</td><td>3</td></tr><tr><td>Maspeth</td><td>1</td></tr><tr><td>Prospect Heights</td><td>1</td></tr><tr><td>Cypress Hills</td><td>2</td></tr><tr><td>East Flatbush</td><td>1</td></tr><tr><td>South Ozone Park</td><td>1</td></tr><tr><td>Upper East Side</td><td>7</td></tr><tr><td>Arverne</td><td>1</td></tr><tr><td>Hell's Kitchen</td><td>7</td></tr><tr><td>Harlem</td><td>13</td></tr><tr><td>Queens Village</td><td>1</td></tr><tr><td>Midtown</td><td>4</td></tr><tr><td>Murray Hill</td><td>1</td></tr><tr><td>Carmen</td><td>1</td></tr><tr><td>Pelham Gardens</td><td>2</td></tr><tr><td>Inwood</td><td>1</td></tr><tr><td>Queens</td><td>5630</td></tr><tr><td>Douglaston</td><td>1</td></tr><tr><td>Greenpoint</td><td>1</td></tr><tr><td>Springfield Gardens</td><td>1</td></tr><tr><td>Cambria Heights</td><td>1</td></tr><tr><td>Mott Haven</td><td>5</td></tr><tr><td>Briarwood</td><td>1</td></tr><tr><td>Fort Greene</td><td>1</td></tr><tr><td>Clinton Hill</td><td>1</td></tr><tr><td>Throgs Neck</td><td>1</td></tr><tr><td>Upper West Side</td><td>3</td></tr><tr><td>Staten Island</td><td>370</td></tr><tr><td>Williamsburg</td><td>6</td></tr><tr><td>Red Hook</td><td>1</td></tr><tr><td>Flushing</td><td>3</td></tr><tr><td>197400421</td><td>1</td></tr><tr><td>Eltingville</td><td>1</td></tr><tr><td>Longwood</td><td>2</td></tr><tr><td>Borough Park</td><td>1</td></tr><tr><td>Gramercy</td><td>1</td></tr><tr><td>East Village</td><td>4</td></tr><tr><td>Flatbush</td><td>2</td></tr><tr><td>Morningside Heights</td><td>3</td></tr><tr><td>Ditmars Steinway</td><td>3</td></tr><tr><td>Bath Beach</td><td>1</td></tr><tr><td>Little Neck</td><td>1</td></tr><tr><td>Edgemere</td><td>1</td></tr><tr><td>Concourse Village</td><td>1</td></tr><tr><td>Canarsie</td><td>4</td></tr><tr><td>West Village</td><td>1</td></tr><tr><td>NoHo</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# ##### Most Popular and Least Popular Neighbourhood_group

# %%
most_popular = neighbourhood_group_df.orderBy(desc("count")).limit(1)
least_popular = neighbourhood_group_df.orderBy(asc("count")).limit(1)

result = most_popular.union(least_popular)
display(result)

print("Most Popular Neighbourhood_group: ", most_popular.first()['neighbourhood_group'])
print("Least Popular Neighbourhood_group: ", least_popular.first()['neighbourhood_group'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood_group</th><th>count</th></tr></thead><tbody><tr><td>Manhattan</td><td>21598</td></tr><tr><td>SoHo</td><td>1</td></tr></tbody></table></div>
# Most Popular Neighbourhood_group:  Manhattan
# Least Popular Neighbourhood_group:  SoHo

# %% [markdown]
# ##### Price distribution across neighbourhood_group

# %%
price_dist_df = df.filter(col('neighbourhood_group').isNotNull()).groupBy("neighbourhood_group").agg(
    count("*").alias("listing_count"),
    avg("price").alias("avg_price"),
    min("price").alias("min_price"),
    max("price").alias("max_price"),
    stddev("price").alias("stddev_price")
).orderBy("avg_price", ascending=False)

display(price_dist_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood_group</th><th>listing_count</th><th>avg_price</th><th>min_price</th><th>max_price</th><th>stddev_price</th></tr></thead><tbody><tr><td>Manhattan</td><td>21598</td><td>196.72428002592832</td><td>0</td><td>10000</td><td>288.58852684878434</td></tr><tr><td>Brooklyn</td><td>20057</td><td>124.39771650795234</td><td>0</td><td>10000</td><td>187.03362186726287</td></tr><tr><td>Staten Island</td><td>370</td><td>114.99459459459459</td><td>13</td><td>5000</td><td>278.66814480677914</td></tr><tr><td>Queens</td><td>5630</td><td>99.57690941385435</td><td>10</td><td>10000</td><td>167.53040318660925</td></tr><tr><td>Bronx</td><td>1080</td><td>87.7287037037037</td><td>0</td><td>2500</td><td>107.19924849905865</td></tr><tr><td>Greenwich Village</td><td>2</td><td>55.5</td><td>31</td><td>80</td><td>34.64823227814083</td></tr><tr><td>Jackson Heights</td><td>2</td><td>16.0</td><td>2</td><td>30</td><td>19.79898987322333</td></tr><tr><td>Brooklyn Heights</td><td>1</td><td>14.0</td><td>14</td><td>14</td><td>null</td></tr><tr><td>Clinton Hill</td><td>1</td><td>14.0</td><td>14</td><td>14</td><td>null</td></tr><tr><td>Upper West Side</td><td>3</td><td>13.0</td><td>3</td><td>30</td><td>14.798648586948742</td></tr><tr><td>Midwood</td><td>3</td><td>12.666666666666666</td><td>1</td><td>35</td><td>19.347695814575268</td></tr><tr><td>Astoria</td><td>2</td><td>12.0</td><td>3</td><td>21</td><td>12.727922061357855</td></tr><tr><td>Flushing</td><td>3</td><td>10.333333333333334</td><td>1</td><td>28</td><td>15.307950004273378</td></tr><tr><td>Midtown</td><td>4</td><td>9.0</td><td>2</td><td>30</td><td>14.0</td></tr><tr><td>Randall Manor</td><td>1</td><td>7.0</td><td>7</td><td>7</td><td>null</td></tr><tr><td>Williamsburg</td><td>6</td><td>6.333333333333333</td><td>1</td><td>30</td><td>11.621818561080131</td></tr><tr><td>Morningside Heights</td><td>3</td><td>5.0</td><td>3</td><td>6</td><td>1.7320508075688772</td></tr><tr><td>Longwood</td><td>2</td><td>5.0</td><td>5</td><td>5</td><td>0.0</td></tr><tr><td>East Flatbush</td><td>1</td><td>4.0</td><td>4</td><td>4</td><td>null</td></tr><tr><td>Crown Heights</td><td>3</td><td>3.6666666666666665</td><td>3</td><td>5</td><td>1.1547005383792517</td></tr><tr><td>Ditmars Steinway</td><td>3</td><td>3.3333333333333335</td><td>1</td><td>6</td><td>2.5166114784235836</td></tr><tr><td>Harlem</td><td>13</td><td>3.3076923076923075</td><td>1</td><td>7</td><td>2.097006413303473</td></tr><tr><td>Bushwick</td><td>4</td><td>3.25</td><td>1</td><td>7</td><td>2.8722813232690143</td></tr><tr><td>East Village</td><td>4</td><td>3.25</td><td>2</td><td>7</td><td>2.5</td></tr><tr><td>Prospect Heights</td><td>1</td><td>3.0</td><td>3</td><td>3</td><td>null</td></tr><tr><td>Edgemere</td><td>1</td><td>3.0</td><td>3</td><td>3</td><td>null</td></tr><tr><td>Chelsea</td><td>2</td><td>3.0</td><td>2</td><td>4</td><td>1.4142135623730951</td></tr><tr><td>Woodhaven</td><td>3</td><td>3.0</td><td>3</td><td>3</td><td>0.0</td></tr><tr><td>West Village</td><td>1</td><td>3.0</td><td>3</td><td>3</td><td>null</td></tr><tr><td>SoHo</td><td>1</td><td>3.0</td><td>3</td><td>3</td><td>null</td></tr><tr><td>Washington Heights</td><td>4</td><td>2.75</td><td>2</td><td>3</td><td>0.5</td></tr><tr><td>East Harlem</td><td>5</td><td>2.6</td><td>2</td><td>3</td><td>0.5477225575051662</td></tr><tr><td>Elmhurst</td><td>7</td><td>2.5714285714285716</td><td>1</td><td>7</td><td>2.439750182371333</td></tr><tr><td>Queens Village</td><td>1</td><td>2.0</td><td>2</td><td>2</td><td>null</td></tr><tr><td>Pelham Gardens</td><td>2</td><td>2.0</td><td>2</td><td>2</td><td>0.0</td></tr><tr><td>Bath Beach</td><td>1</td><td>2.0</td><td>2</td><td>2</td><td>null</td></tr><tr><td>Murray Hill</td><td>1</td><td>2.0</td><td>2</td><td>2</td><td>null</td></tr><tr><td>Prospect-Lefferts Gardens</td><td>2</td><td>2.0</td><td>2</td><td>2</td><td>0.0</td></tr><tr><td>Arverne</td><td>1</td ...

# %% [markdown]
# ##### Most expensive and Least Expensive neighbourhood_group
# Manhattan is the most expensive and East Elmhurst is the least expensive neighbourhood group

# %%
price_df = df.filter((col('neighbourhood_group').isNotNull()) & (col('price').isNotNull())).groupBy("neighbourhood_group").agg(
    avg("price").alias("avg_price"))

most_expensive = price_df.orderBy(desc("avg_price")).limit(1)
most_cheap = price_df.orderBy(asc("avg_price")).limit(1)
result = most_expensive.union(most_cheap)
display(result)

print("Most Expensive Neighbourhood_group: ", most_expensive.first()['neighbourhood_group'])
print("Most Economical Neighbourhood_group: ", most_cheap.first()['neighbourhood_group'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood_group</th><th>avg_price</th></tr></thead><tbody><tr><td>Manhattan</td><td>196.72428002592832</td></tr><tr><td>East Elmhurst</td><td>1.0</td></tr></tbody></table></div>
# Most Expensive Neighbourhood_group:  Manhattan
# Most Economical Neighbourhood_group:  East Elmhurst

# %% [markdown]
# ##### Popularity of Neighbourhood

# %%
display(df.filter(col('neighbourhood').isNotNull()).groupBy('neighbourhood').agg(count('*').alias('count')).orderBy(desc('count')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood</th><th>count</th></tr></thead><tbody><tr><td>Williamsburg</td><td>3914</td></tr><tr><td>Bedford-Stuyvesant</td><td>3705</td></tr><tr><td>Harlem</td><td>2645</td></tr><tr><td>Bushwick</td><td>2460</td></tr><tr><td>Upper West Side</td><td>1968</td></tr><tr><td>Hell's Kitchen</td><td>1951</td></tr><tr><td>East Village</td><td>1849</td></tr><tr><td>Upper East Side</td><td>1791</td></tr><tr><td>Crown Heights</td><td>1561</td></tr><tr><td>Midtown</td><td>1541</td></tr><tr><td>Greenpoint</td><td>1114</td></tr><tr><td>East Harlem</td><td>1112</td></tr><tr><td>Chelsea</td><td>1111</td></tr><tr><td>Lower East Side</td><td>911</td></tr><tr><td>Astoria</td><td>898</td></tr><tr><td>Washington Heights</td><td>895</td></tr><tr><td>West Village</td><td>767</td></tr><tr><td>Financial District</td><td>744</td></tr><tr><td>Flatbush</td><td>619</td></tr><tr><td>Clinton Hill</td><td>571</td></tr><tr><td>Long Island City</td><td>534</td></tr><tr><td>Prospect-Lefferts Gardens</td><td>533</td></tr><tr><td>Park Slope</td><td>506</td></tr><tr><td>East Flatbush</td><td>499</td></tr><tr><td>Fort Greene</td><td>488</td></tr><tr><td>Murray Hill</td><td>484</td></tr><tr><td>Kips Bay</td><td>470</td></tr><tr><td>Ridgewood</td><td>423</td></tr><tr><td>Flushing</td><td>423</td></tr><tr><td>Sunset Park</td><td>390</td></tr><tr><td>Greenwich Village</td><td>390</td></tr><tr><td>Chinatown</td><td>367</td></tr><tr><td>Sunnyside</td><td>363</td></tr><tr><td>SoHo</td><td>357</td></tr><tr><td>Prospect Heights</td><td>356</td></tr><tr><td>Morningside Heights</td><td>343</td></tr><tr><td>Gramercy</td><td>337</td></tr><tr><td>Ditmars Steinway</td><td>306</td></tr><tr><td>Theater District</td><td>288</td></tr><tr><td>South Slope</td><td>284</td></tr><tr><td>Nolita</td><td>253</td></tr><tr><td>Inwood</td><td>251</td></tr><tr><td>Gowanus</td><td>247</td></tr><tr><td>Woodside</td><td>234</td></tr><tr><td>Carroll Gardens</td><td>233</td></tr><tr><td>Jamaica</td><td>231</td></tr><tr><td>Elmhurst</td><td>230</td></tr><tr><td>East New York</td><td>217</td></tr><tr><td>Jackson Heights</td><td>184</td></tr><tr><td>East Elmhurst</td><td>183</td></tr><tr><td>Tribeca</td><td>177</td></tr><tr><td>Boerum Hill</td><td>177</td></tr><tr><td>Kensington</td><td>175</td></tr><tr><td>Sheepshead Bay</td><td>163</td></tr><tr><td>Windsor Terrace</td><td>157</td></tr><tr><td>Brooklyn Heights</td><td>153</td></tr><tr><td>Forest Hills</td><td>144</td></tr><tr><td>Canarsie</td><td>143</td></tr><tr><td>Bay Ridge</td><td>141</td></tr><tr><td>Borough Park</td><td>135</td></tr><tr><td>Cypress Hills</td><td>133</td></tr><tr><td>Little Italy</td><td>121</td></tr><tr><td>Maspeth</td><td>109</td></tr><tr><td>Rego Park</td><td>106</td></tr><tr><td>Midwood</td><td>106</td></tr><tr><td>Cobble Hill</td><td>99</td></tr><tr><td>Richmond Hill</td><td>94</td></tr><tr><td>Woodhaven</td><td>85</td></tr><tr><td>Springfield Gardens</td><td>84</td></tr><tr><td>Flatlands</td><td>83</td></tr><tr><td>Downtown Brooklyn</td><td>83</td></tr><tr><td>Flatiron District</td><td>80</td></tr><tr><td>Red Hook</td><td>78</td></tr><tr><td>Roosevelt Island</td><td>77</td></tr><tr><td>NoHo</td><td>76</td></tr><tr><td>St. Albans</td><td>76</td></tr><tr><td>Arverne</td><td>76</td></tr><tr><td>Bensonhurst</td><td>75</td></tr><tr><td>Brighton Beach</td><td>75</td></tr><tr><td>Two Bridges</td><td>72</td></tr><tr><td>Battery Park City</td><td>70</td></tr><tr><td>Kingsbridge</td><td>70</td></tr><tr><td>Gravesend</td><td>68</td></tr><tr><td>Corona</td><td>64</td></tr><tr><td>Fordham</td><td>63</td></tr><tr><td>Ozone Park</td><td>62</td></tr><tr><td>Brownsville</td><td>61</td></tr><tr><td>Longwood</td><td>60</td></tr><tr><td>Queens Village</td><td>59</td></tr><tr><td>Rosedale</td><td>59</td></tr><tr><td>Rockaway Beach</td><td>56</td></tr><tr><td>Fort Hamilton</td><td>55</td></tr><tr><td>Briarwood</td><td>55</td>< ...

# %% [markdown]
# ##### Getting valid neighbourhood from the datasets since there are numeric values and nulls present in the field

# %%
valid_neighbourhood = df.filter(~col('neighbourhood').like("40%") & col("neighbourhood").isNotNull())

display(valid_neighbourhood.groupBy('neighbourhood').agg(count('*').alias('count')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood</th><th>count</th></tr></thead><tbody><tr><td>Financial District</td><td>744</td></tr><tr><td>East Elmhurst</td><td>183</td></tr><tr><td>Greenwich Village</td><td>390</td></tr><tr><td>Dongan Hills</td><td>7</td></tr><tr><td>Crown Heights</td><td>1561</td></tr><tr><td>Morris Park</td><td>15</td></tr><tr><td>Carroll Gardens</td><td>233</td></tr><tr><td>Elmhurst</td><td>230</td></tr><tr><td>Willowbrook</td><td>1</td></tr><tr><td>Co-op City</td><td>2</td></tr><tr><td>Bay Ridge</td><td>141</td></tr><tr><td>Brownsville</td><td>61</td></tr><tr><td>Sunnyside</td><td>363</td></tr><tr><td>Jamaica Estates</td><td>19</td></tr><tr><td>Marble Hill</td><td>12</td></tr><tr><td>Woodhaven</td><td>85</td></tr><tr><td>Fordham</td><td>63</td></tr><tr><td>Fresh Meadows</td><td>32</td></tr><tr><td>Roosevelt Island</td><td>77</td></tr><tr><td>Brooklyn</td><td>2</td></tr><tr><td>SoHo</td><td>357</td></tr><tr><td>Claremont Village</td><td>28</td></tr><tr><td>Lighthouse Hill</td><td>2</td></tr><tr><td>Silver Lake</td><td>2</td></tr><tr><td>Hunts Point</td><td>18</td></tr><tr><td>Arden Heights</td><td>4</td></tr><tr><td>Norwood</td><td>31</td></tr><tr><td>Kips Bay</td><td>470</td></tr><tr><td>Bedford-Stuyvesant</td><td>3705</td></tr><tr><td>Richmond Hill</td><td>94</td></tr><tr><td>East Morrisania</td><td>10</td></tr><tr><td>Riverdale</td><td>11</td></tr><tr><td>Van Nest</td><td>11</td></tr><tr><td>Windsor Terrace</td><td>157</td></tr><tr><td>Midland Beach</td><td>6</td></tr><tr><td>Civic Center</td><td>52</td></tr><tr><td>Bronxdale</td><td>19</td></tr><tr><td>College Point</td><td>19</td></tr><tr><td>Chelsea</td><td>1111</td></tr><tr><td>Rossville</td><td>1</td></tr><tr><td>Kew Gardens</td><td>32</td></tr><tr><td>Sea Gate</td><td>7</td></tr><tr><td>East Harlem</td><td>1112</td></tr><tr><td>Bushwick</td><td>2460</td></tr><tr><td>Astoria</td><td>898</td></tr><tr><td>Jackson Heights</td><td>184</td></tr><tr><td>North Riverdale</td><td>10</td></tr><tr><td>Jamaica Hills</td><td>8</td></tr><tr><td>Navy Yard</td><td>14</td></tr><tr><td>Morris Heights</td><td>17</td></tr><tr><td>East New York</td><td>217</td></tr><tr><td>Huguenot</td><td>3</td></tr><tr><td>Midwood</td><td>106</td></tr><tr><td>Grymes Hill</td><td>7</td></tr><tr><td>Castleton Corners</td><td>4</td></tr><tr><td>Woodside</td><td>234</td></tr><tr><td>St. Albans</td><td>76</td></tr><tr><td>Gravesend</td><td>68</td></tr><tr><td>Tottenville</td><td>7</td></tr><tr><td>Middle Village</td><td>31</td></tr><tr><td>Jamaica</td><td>231</td></tr><tr><td>Rosebank</td><td>7</td></tr><tr><td>Prospect-Lefferts Gardens</td><td>533</td></tr><tr><td>Arrochar</td><td>21</td></tr><tr><td>New Brighton</td><td>5</td></tr><tr><td>Schuylerville</td><td>13</td></tr><tr><td>Grant City</td><td>6</td></tr><tr><td>Stuyvesant Town</td><td>36</td></tr><tr><td>Graniteville</td><td>3</td></tr><tr><td>Brooklyn Heights</td><td>153</td></tr><tr><td>Cobble Hill</td><td>99</td></tr><tr><td>Woodrow</td><td>1</td></tr><tr><td>Bayswater</td><td>17</td></tr><tr><td>Prince's Bay</td><td>4</td></tr><tr><td>Tompkinsville</td><td>42</td></tr><tr><td>South Beach</td><td>8</td></tr><tr><td>Flatiron District</td><td>80</td></tr><tr><td>Washington Heights</td><td>895</td></tr><tr><td>Randall Manor</td><td>18</td></tr><tr><td>Long Island City</td><td>534</td></tr><tr><td>Laurelton</td><td>18</td></tr><tr><td>Westchester Square</td><td>10</td></tr><tr><td>Kensington</td><td>175</td></tr><tr><td>Battery Park City</td><td>70</td></tr><tr><td>Maspeth</td><td>109</td></tr><tr><td>Oakwood</td><td>5</td></tr><tr><td>Fort Hamilton</td><td>55</td></tr><tr><td>Ridgewood</td><td>423</td></tr><tr><td>Prospect Heights</td><td>356</td></tr><tr><td>Cypress Hills</td><td>133</td></tr><tr><td>Manhattan Beach</td><td>8</td></tr><tr><td>Stapleton</td><td>27</td></tr><tr><td>Soundview</td><td>15</td></tr><tr><td>Holliswood</td><td>4</td>< ...

# %% [markdown]
# ##### Most Popular and Least Popular Neighbourhood
# Williamsburg is the most popular and Willowbrook is the least popular neighbourhood

# %%
mp_neighbourhood = valid_neighbourhood.groupBy('neighbourhood').agg(count('*').alias('count')).orderBy(desc('count')).limit(1)
lp_neighbourhood = valid_neighbourhood.groupBy('neighbourhood').agg(count('*').alias('count')).orderBy(asc('count')).limit(1)
result = mp_neighbourhood.union(lp_neighbourhood)
display(result)

print("Most Popular Neighbourhood: ", mp_neighbourhood.first()['neighbourhood'])
print("Least Popular Neighbourhood: ", lp_neighbourhood.first()['neighbourhood'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood</th><th>count</th></tr></thead><tbody><tr><td>Williamsburg</td><td>3914</td></tr><tr><td>Willowbrook</td><td>1</td></tr></tbody></table></div>
# Most Popular Neighbourhood:  Williamsburg
# Least Popular Neighbourhood:  Willowbrook

# %% [markdown]
# ##### Most expensive and least expensive neighbourboods
# Fort Wadsworth is the most expensive and Bull's Head is the least expensive neighbourhood

# %%
me_neighbourhood = valid_neighbourhood.filter(col('price').isNotNull()).groupBy('neighbourhood').agg(round(avg('price'),2).alias('avg_price')).orderBy(desc('avg_price')).limit(1)
le_neighbourhood = valid_neighbourhood.filter(col('price').isNotNull()).groupBy('neighbourhood').agg(round(avg('price'),2).alias('avg_price')).orderBy(asc('avg_price')).limit(1)

result = me_neighbourhood.union(le_neighbourhood)
display(result)

print("Most Expensive Neighbourhood: ", me_neighbourhood.first()['neighbourhood'])
print("Most Economical Neighbourhood: ", le_neighbourhood.first()['neighbourhood'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>neighbourhood</th><th>avg_price</th></tr></thead><tbody><tr><td>Fort Wadsworth</td><td>800.0</td></tr><tr><td>Bull's Head</td><td>47.33</td></tr></tbody></table></div>
# Most Expensive Neighbourhood:  Fort Wadsworth
# Most Economical Neighbourhood:  Bull's Head

# %% [markdown]
# #### Host Analysis

# %% [markdown]
# ##### Top 5 most busy hosts

# %%
display(df.filter((col('host_id').isNotNull()) & (col('host_name').isNotNull()) & (col('calculated_host_listings_count')>10)).select('host_id','host_name','calculated_host_listings_count').distinct().orderBy(desc('calculated_host_listings_count')).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host_id</th><th>host_name</th><th>calculated_host_listings_count</th></tr></thead><tbody><tr><td>219517861</td><td>Sonder (NYC)</td><td>327</td></tr><tr><td>107434423</td><td>Blueground</td><td>232</td></tr><tr><td>30283594</td><td>Kara</td><td>121</td></tr><tr><td>137358866</td><td>Kazuya</td><td>103</td></tr><tr><td>12243051</td><td>Sonder</td><td>96</td></tr></tbody></table></div>

# %% [markdown]
# ##### Most Expensive and Least Expensive Hosts

# %%
expensive_host = df.filter(col('host_id').isNotNull() & col('host_name').isNotNull() & col('price').isNotNull()).groupBy('host_name').agg(avg('price').alias('avg_price')).orderBy(desc('avg_price')).limit(1)
economical_host = df.filter(col('host_id').isNotNull() & col('host_name').isNotNull() & col('price').isNotNull()).groupBy('host_name').agg(avg('price').alias('avg_price')).orderBy(asc('avg_price')).limit(1)

result = expensive_host.union(economical_host)
display(result)

print("Most Expensive Host: ", expensive_host.first()['host_name'])
print("Most Economical Host: ", economical_host.first()['host_name'])
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host_name</th><th>avg_price</th></tr></thead><tbody><tr><td>Olson</td><td>9999.0</td></tr><tr><td>Qiuchi</td><td>0.0</td></tr></tbody></table></div>
# Most Expensive Host:  Olson
# Most Economical Host:  Qiuchi

# %% [markdown]
# #### Availability Analysis

# %% [markdown]
# ##### Listings with high availability (greater than 200 days)

# %%
count_high_availability = df.filter(col('availability_365') > 200).count()
print(f"Listings with high availability: {count_high_availability}")
# Out:
# Listings with high availability: 13275

# %%
availability_by_room = valid_df.groupBy('room_type').agg(
    count('*').alias('listing_count'),
    avg('availability_365').alias('avg_availability'),
    max('availability_365').alias('max_availability'),
    min('availability_365').alias('min_availability'),
    stddev('availability_365').alias('stddev_availability')
).orderBy('avg_availability', ascending=False)

display(availability_by_room)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>room_type</th><th>listing_count</th><th>avg_availability</th><th>max_availability</th><th>min_availability</th><th>stddev_availability</th></tr></thead><tbody><tr><td>Shared room</td><td>1158</td><td>161.85837651122625</td><td>365</td><td>0</td><td>151.40196680384472</td></tr><tr><td>Entire home/apt</td><td>25348</td><td>111.84744358529272</td><td>365</td><td>0</td><td>129.8022904050754</td></tr><tr><td>Private room</td><td>22229</td><td>110.92401817445679</td><td>365</td><td>0</td><td>132.0546938773315</td></tr></tbody></table></div>
